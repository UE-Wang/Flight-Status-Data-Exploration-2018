# %% [markdown]
# # Part 1 Data preparation

# %%
# import the neede package
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.warn('DelftStack')
warnings.warn('Do not show this message')
print("No Warning Shown")
# Out:
# No Warning Shown

# %%
flight = pd.read_csv("/Users/UE/Desktop/flight2018.csv")

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5689512 entries, 0 to 5689511
# Data columns (total 61 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   FlightDate                               object
#  1   Airline                                  object
#  2   Origin                                   object
#  3   Dest                                     object
#  4   Cancelled                                bool
#  5   Diverted                                 bool
#  6   CRSDepTime                               int64
#  7   DepTime                                  float64
#  8   DepDelayMinutes                          float64
#  9   DepDelay                                 float64
#  10  ArrTime                                  float64
#  11  ArrDelayMinutes                          float64
#  12  AirTime                                  float64
#  13  CRSElapsedTime                           float64
#  14  ActualElapsedTime                        float64
#  15  Distance                                 float64
#  16  Year                                     int64
#  17  Quarter                                  int64
#  18  Month                                    int64
#  19  DayofMonth                               int64
#  20  DayOfWeek                                int64
#  21  Marketing_Airline_Network                object
#  22  Operated_or_Branded_Code_Share_Partners  object
#  23  DOT_ID_Marketing_Airline                 int64
#  24  IATA_Code_Marketing_Airline              object
#  25  Flight_Number_Marketing_Airline          int64
#  26  Operating_Airline                        object
#  27  DOT_ID_Operating_Airline                 int64
#  28  IATA_Code_Operating_Airline              object
#  29  Tail_Number                              object
#  30  Flight_Number_Operating_Airline          int64
#  31  OriginAirportID                          int64
#  32  OriginAirportSeqID                       int64
#  33  OriginCityMarketID                       int64
#  34  OriginCityName                           object
#  35  OriginState                              object
#  36  OriginStateFips                          int64
#  37  OriginStateName                          object
#  38  OriginWac                                int64
#  39  DestAirportID                            int64
#  40  DestAirportSeqID                         int64
#  41  DestCityMarketID                         int64
#  42  DestCityName                             object
#  43  DestState                                object
#  44  DestStateFips                            int64
#  45  DestStateName                            object
#  46  DestWac                                  int64
#  47  DepDel15                                 float64
#  48  DepartureDelayGroups                     float64
#  49  DepTimeBlk                               object
#  50  TaxiOut                                  float64
#  51  WheelsOff                                float64
#  52  WheelsOn                                 float64
#  53  TaxiIn                                   float64
#  54  CRSArrTime                               int64
#  55  ArrDelay                                 float64
#  56  ArrDel15                                 float64
#  57  ArrivalDelayGroups                       float64
#  58  ArrTimeBlk                               object
#  59  DistanceGroup                            int64
#  60  DivAirportLandings                       float64
# dtypes: bool(2), float64(19), int64(22), object(18)
# memory usage: 2.5+ GB

# %%
flight['Cancelled'].value_counts()
# Out:
# False    5601139
# True       88373
# Name: Cancelled, dtype: int64

# %%
# drop the unneeded columns
flight = flight.drop(["Marketing_Airline_Network", "DOT_ID_Marketing_Airline", "IATA_Code_Marketing_Airline", 
           "OriginAirportSeqID", "OriginCityMarketID", "OriginStateFips", "DestAirportSeqID", 
           "DestCityMarketID", "DestStateFips", "Operated_or_Branded_Code_Share_Partners",
            "DOT_ID_Operating_Airline", "Flight_Number_Marketing_Airline", "IATA_Code_Operating_Airline",
            "Year", "Tail_Number", "OriginAirportID", "OriginAirportID", "DestAirportID",
            "DivAirportLandings","Operating_Airline","OriginState", "OriginWac","DestState",
            "DestWac","DepDelayMinutes", "ArrDelayMinutes","DestCityName","OriginCityName",
            "CRSDepTime", "Flight_Number_Operating_Airline","CRSArrTime", "Diverted",
            "ArrDel15", "DepDel15", "ArrivalDelayGroups", "DepartureDelayGroups", "DistanceGroup",
            "TaxiOut","TaxiIn", "WheelsOff", "WheelsOn" ,"OriginStateName", "DestStateName",], axis = 1)
flight
# Out:
#          FlightDate                      Airline Origin Dest  Cancelled  \
# 0        2018-01-23            Endeavor Air Inc.    ABY  ATL      False
# 1        2018-01-24            Endeavor Air Inc.    ABY  ATL      False
# 2        2018-01-25            Endeavor Air Inc.    ABY  ATL      False
# 3        2018-01-26            Endeavor Air Inc.    ABY  ATL      False
# 4        2018-01-27            Endeavor Air Inc.    ABY  ATL      False
# ...             ...                          ...    ...  ...        ...
# 5689507  2018-09-11  Air Wisconsin Airlines Corp    SCE  IAD      False
# 5689508  2018-09-11  Air Wisconsin Airlines Corp    IAD  GSO      False
# 5689509  2018-09-11  Air Wisconsin Airlines Corp    EVV  ORD      False
# 5689510  2018-09-11  Air Wisconsin Airlines Corp    ORD  HPN      False
# 5689511  2018-09-11  Air Wisconsin Airlines Corp    HPN  ORD      False
#
#          DepTime  DepDelay  ArrTime  AirTime  CRSElapsedTime  \
# 0         1157.0      -5.0   1256.0     38.0            62.0
# 1         1157.0      -5.0   1258.0     36.0            62.0
# 2         1153.0      -9.0   1302.0     40.0            62.0
# 3         1150.0     -12.0   1253.0     35.0            62.0
# 4         1355.0      -5.0   1459.0     36.0            60.0
# ...          ...       ...      ...      ...             ...
# 5689507   1433.0     -12.0   1515.0     35.0            61.0
# 5689508   1224.0     -11.0   1344.0     43.0            80.0
# 5689509   1016.0     -14.0   1137.0     54.0            94.0
# 5689510   1403.0      -7.0   1717.0    104.0           136.0
# 5689511   1754.0      -6.0   1919.0    116.0           153.0
#
#          ActualElapsedTime  Distance  Quarter  Month  DayofMonth  DayOfWeek  \
# 0                     59.0     145.0        1      1          23          2
# 1                     61.0     145.0        1      1          24          3
# 2                     69.0     145.0        1      1          25          4
# 3                     63.0     145.0        1      1          26          5
# 4                     64.0     145.0        1      1          27          6
# ...                    ...       ...      ...    ...         ...        ...
# 5689507               42.0     133.0        3      9          11          2
# 5689508               80.0     239.0        3      9          11          2
# 5689509               81.0     272.0        3      9          11          2
# 5689510              134.0     738.0        3      9          11          2
# 5689511              145.0     738.0        3      9          11          2
#
#         DepTimeBlk  ArrDelay ArrTimeBlk
# 0        1200-1259      -8.0  1300-1359
# 1        1200-1259      -6.0  1300-1359
# 2        1200-1259      -2.0  1300-1359
# 3        1200-1259     -11.0  1300-1359
# 4        1400-1459      -1.0  1500-1559
# ...            ...       ...        ...
# 5689507  1400-1459     -31.0  1500-1559
# 5689508  1200-1259     -11.0  1300-1359
# 5689509  1000-1059     -27.0  1200-1259
# 5689510  1400-1459      -9.0  1700-1759
# 5689511  1800-1859     -14.0  1900-1959
#
# [5689512 rows x 19 columns]

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5689512 entries, 0 to 5689511
# Data columns (total 19 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   FlightDate         object
#  1   Airline            object
#  2   Origin             object
#  3   Dest               object
#  4   Cancelled          bool
#  5   DepTime            float64
#  6   DepDelay           float64
#  7   ArrTime            float64
#  8   AirTime            float64
#  9   CRSElapsedTime     float64
#  10  ActualElapsedTime  float64
#  11  Distance           float64
#  12  Quarter            int64
#  13  Month              int64
#  14  DayofMonth         int64
#  15  DayOfWeek          int64
#  16  DepTimeBlk         object
#  17  ArrDelay           float64
#  18  ArrTimeBlk         object
# dtypes: bool(1), float64(8), int64(4), object(6)
# memory usage: 786.8+ MB

# %% [markdown]
# #### Flight been cancelled means also doesn't have departure and arrive data.
# #### We will drop the data that contain missing values.
# ## Add the needed column

# %%
# 1. Flight_Status column

def Flight_Status(value):
    if value <= 0.0:
        return "Early Depart_On Time"
    if 0.0 < value <= 15.0:
        return "DepDelay < 15 min"
    elif 15.0 < value <= 30.0:
        return "DepDelay 16-30 min"
    elif 30.0 < value <= 60.0:
        return "DepDelay 31-60 min"
    elif value > 60.0:
        return "DepDelay > 61"
    else:
        return "Cancelled"

flight['Flight_Status'] = flight['DepDelay'].map(Flight_Status)
display(flight.head())
# Out:
#    FlightDate            Airline Origin Dest  Cancelled  DepTime  DepDelay  \
# 0  2018-01-23  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 1  2018-01-24  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 2  2018-01-25  Endeavor Air Inc.    ABY  ATL      False   1153.0      -9.0
# 3  2018-01-26  Endeavor Air Inc.    ABY  ATL      False   1150.0     -12.0
# 4  2018-01-27  Endeavor Air Inc.    ABY  ATL      False   1355.0      -5.0
#
#    ArrTime  AirTime  CRSElapsedTime  ActualElapsedTime  Distance  Quarter  \
# 0   1256.0     38.0            62.0               59.0     145.0        1
# 1   1258.0     36.0            62.0               61.0     145.0        1
# 2   1302.0     40.0            62.0               69.0     145.0        1
# 3   1253.0     35.0            62.0               63.0     145.0        1
# 4   1459.0     36.0            60.0               64.0     145.0        1
#
#    Month  DayofMonth  DayOfWeek DepTimeBlk  ArrDelay ArrTimeBlk  \
# 0      1          23          2  1200-1259      -8.0  1300-1359
# 1      1          24          3  1200-1259      -6.0  1300-1359
# 2      1          25          4  1200-1259      -2.0  1300-1359
# 3      1          26          5  1200-1259     -11.0  1300-1359
# 4      1          27          6  1400-1459      -1.0  1500-1559
#
#           Flight_Status
# 0  Early Depart_On Time
# 1  Early Depart_On Time
# 2  Early Depart_On Time
# 3  Early Depart_On Time
# 4  Early Depart_On Time

# %%
# 2. Distance_level column:

def Distance_level(value):
    if value <= 300.0:
        return "Distance < 300"
    if 300.0 < value <= 600.0:
        return "Distance 300-600 mile"
    elif 600.0 < value <= 900.0:
        return "Distance 600-900 mile"
    elif 900.0 < value <= 1200.0:
        return "Distance 900-1200 mile"
    elif 1200.0 < value <= 1500.0:
        return "Distance 1200-1500 mile"
    elif 1500.0 < value <= 1800.0:
        return "Distance 1500-1800 mile"
    elif 1800.0 < value <= 2100.0:
        return "Distance 1800-2100 mile"
    elif 2100.0 < value <= 2400.0:
        return "Distance 2100-2400 mile"
    elif 2400.0 < value <= 2700.0:
        return "Distance 2400-2700 mile"
    elif value > 2700.0:
        return "Distance > 2700 mile"

flight['Distance_level'] = flight['Distance'].map(Distance_level)
display(flight.head())
# Out:
#    FlightDate            Airline Origin Dest  Cancelled  DepTime  DepDelay  \
# 0  2018-01-23  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 1  2018-01-24  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 2  2018-01-25  Endeavor Air Inc.    ABY  ATL      False   1153.0      -9.0
# 3  2018-01-26  Endeavor Air Inc.    ABY  ATL      False   1150.0     -12.0
# 4  2018-01-27  Endeavor Air Inc.    ABY  ATL      False   1355.0      -5.0
#
#    ArrTime  AirTime  CRSElapsedTime  ...  Distance  Quarter  Month  \
# 0   1256.0     38.0            62.0  ...     145.0        1      1
# 1   1258.0     36.0            62.0  ...     145.0        1      1
# 2   1302.0     40.0            62.0  ...     145.0        1      1
# 3   1253.0     35.0            62.0  ...     145.0        1      1
# 4   1459.0     36.0            60.0  ...     145.0        1      1
#
#    DayofMonth  DayOfWeek  DepTimeBlk ArrDelay  ArrTimeBlk  \
# 0          23          2   1200-1259     -8.0   1300-1359
# 1          24          3   1200-1259     -6.0   1300-1359
# 2          25          4   1200-1259     -2.0   1300-1359
# 3          26          5   1200-1259    -11.0   1300-1359
# 4          27          6   1400-1459     -1.0   1500-1559
#
#           Flight_Status  Distance_level
# 0  Early Depart_On Time  Distance < 300
# 1  Early Depart_On Time  Distance < 300
# 2  Early Depart_On Time  Distance < 300
# 3  Early Depart_On Time  Distance < 300
# 4  Early Depart_On Time  Distance < 300
#
# [5 rows x 21 columns]

# %%
flight['Distance_level'].value_counts()
# Out:
# Distance 300-600 mile      1622311
# Distance 600-900 mile      1122617
# Distance < 300             1090721
# Distance 900-1200 mile      851085
# Distance 1200-1500 mile     321456
# Distance 1500-1800 mile     263937
# Distance 2400-2700 mile     163152
# Distance 2100-2400 mile     117322
# Distance 1800-2100 mile     108952
# Distance > 2700 mile         27959
# Name: Distance_level, dtype: int64

# %%
# 3. Airport_Size column:

flight['Airport_DailyDep_Avg'] = round((flight.groupby('Origin')['Origin'].transform('count')/365),2)
def Airport_Size(value):
    if value <= 50.0:
        return "Small"
    if 50.0 < value <= 500.0:
        return "Medium"
    elif value > 500.0:
        return "Large"

flight['Airport_Size'] = flight['Airport_DailyDep_Avg'].map(Airport_Size)
display(flight.head())
# Out:
#    FlightDate            Airline Origin Dest  Cancelled  DepTime  DepDelay  \
# 0  2018-01-23  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 1  2018-01-24  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 2  2018-01-25  Endeavor Air Inc.    ABY  ATL      False   1153.0      -9.0
# 3  2018-01-26  Endeavor Air Inc.    ABY  ATL      False   1150.0     -12.0
# 4  2018-01-27  Endeavor Air Inc.    ABY  ATL      False   1355.0      -5.0
#
#    ArrTime  AirTime  CRSElapsedTime  ...  Month  DayofMonth  DayOfWeek  \
# 0   1256.0     38.0            62.0  ...      1          23          2
# 1   1258.0     36.0            62.0  ...      1          24          3
# 2   1302.0     40.0            62.0  ...      1          25          4
# 3   1253.0     35.0            62.0  ...      1          26          5
# 4   1459.0     36.0            60.0  ...      1          27          6
#
#    DepTimeBlk  ArrDelay  ArrTimeBlk         Flight_Status  Distance_level  \
# 0   1200-1259      -8.0   1300-1359  Early Depart_On Time  Distance < 300
# 1   1200-1259      -6.0   1300-1359  Early Depart_On Time  Distance < 300
# 2   1200-1259      -2.0   1300-1359  Early Depart_On Time  Distance < 300
# 3   1200-1259     -11.0   1300-1359  Early Depart_On Time  Distance < 300
# 4   1400-1459      -1.0   1500-1559  Early Depart_On Time  Distance < 300
#
#   Airport_DailyDep_Avg Airport_Size
# 0                 1.37        Small
# 1                 1.37        Small
# 2                 1.37        Small
# 3                 1.37        Small
# 4                 1.37        Small
#
# [5 rows x 23 columns]

# %%
flight['Airport_DailyDep_Avg'].value_counts()
# Out:
# 793.02    289451
# 690.13    251899
# 613.18    223810
# 502.88    183553
# 446.91    163121
#            ...
# 0.21          78
# 0.19          71
# 0.16          58
# 0.14          52
# 0.01           2
# Name: Airport_DailyDep_Avg, Length: 326, dtype: int64

# %%
# Split the data into 2 datasets, one for the cancelled flights data, the other one for Delay flights

flight_can = flight[flight['Cancelled'] != False]
flight_delay = flight[flight['Cancelled'] == False]
flight_delay = flight_delay.dropna(axis=0)
flight_delay
# Out:
#          FlightDate                      Airline Origin Dest  Cancelled  \
# 0        2018-01-23            Endeavor Air Inc.    ABY  ATL      False
# 1        2018-01-24            Endeavor Air Inc.    ABY  ATL      False
# 2        2018-01-25            Endeavor Air Inc.    ABY  ATL      False
# 3        2018-01-26            Endeavor Air Inc.    ABY  ATL      False
# 4        2018-01-27            Endeavor Air Inc.    ABY  ATL      False
# ...             ...                          ...    ...  ...        ...
# 5689507  2018-09-11  Air Wisconsin Airlines Corp    SCE  IAD      False
# 5689508  2018-09-11  Air Wisconsin Airlines Corp    IAD  GSO      False
# 5689509  2018-09-11  Air Wisconsin Airlines Corp    EVV  ORD      False
# 5689510  2018-09-11  Air Wisconsin Airlines Corp    ORD  HPN      False
# 5689511  2018-09-11  Air Wisconsin Airlines Corp    HPN  ORD      False
#
#          DepTime  DepDelay  ArrTime  AirTime  CRSElapsedTime  ...  Month  \
# 0         1157.0      -5.0   1256.0     38.0            62.0  ...      1
# 1         1157.0      -5.0   1258.0     36.0            62.0  ...      1
# 2         1153.0      -9.0   1302.0     40.0            62.0  ...      1
# 3         1150.0     -12.0   1253.0     35.0            62.0  ...      1
# 4         1355.0      -5.0   1459.0     36.0            60.0  ...      1
# ...          ...       ...      ...      ...             ...  ...    ...
# 5689507   1433.0     -12.0   1515.0     35.0            61.0  ...      9
# 5689508   1224.0     -11.0   1344.0     43.0            80.0  ...      9
# 5689509   1016.0     -14.0   1137.0     54.0            94.0  ...      9
# 5689510   1403.0      -7.0   1717.0    104.0           136.0  ...      9
# 5689511   1754.0      -6.0   1919.0    116.0           153.0  ...      9
#
#          DayofMonth  DayOfWeek  DepTimeBlk  ArrDelay  ArrTimeBlk  \
# 0                23          2   1200-1259      -8.0   1300-1359
# 1                24          3   1200-1259      -6.0   1300-1359
# 2                25          4   1200-1259      -2.0   1300-1359
# 3                26          5   1200-1259     -11.0   1300-1359
# 4                27          6   1400-1459      -1.0   1500-1559
# ...             ...        ...         ...       ...         ...
# 5689507          11          2   1400-1459     -31.0   1500-1559
# 5689508          11          2   1200-1259     -11.0   1300-1359
# 5689509          11          2   1000-1059     -27.0   1200-1259
# 5689510          11          2   1400-1459      -9.0   1700-1759
# 5689511          11          2   1800-1859     -14.0   1900-1959
#
#                 Flight_Status         Distance_level Airport_DailyDep_Avg  \
# 0        Early Depart_On Time         Distance < 300                 1.37
# 1        Early Depart_On Time         Distance < 300                 1.37
# 2        Early Depart_On Time         Distance < 300                 1.37
# 3        Early Depart_On Time         Distance < 300                 1.37
# 4        Early Depart_On Time         Distance < 300                 1.37
# ...                       ...                    ...                  ...
# 5689507  Early Depart_On Time         Distance < 300                 7.87
# 5689508  Early Depart_On Time         Distance < 300               235.35
# 5689509  Early Depart_On Time         Distance < 300                 8.69
# 5689510  Early Depart_On Time  Distance 600-900 mile               793.02
# 5689511  Early Depart_On Time  Distance 600-900 mile                21.88
#
#         Airport_Size
# 0              Small
# 1              Small
# 2              Small
# 3              Small
# 4              Small
# ...              ...
# 5689507        Small
# 5689508       Medium
# 5689509        Small
# 5689510        Large
# 5689511        Small
#
# [5578618 rows x 23 columns]

# %%
# 4. delay_level column:

# Calculate the delay difference using the arrival delay minus departure delay within the delay dataset
flight_delay['Delay_diff'] = flight_delay['ArrDelay'] - flight_delay['DepDelay']
def delay_level(value):
    if value <= 0:
        return "Diff < 0"
    if 0.0 < value <= 15.0:
        return "Diff < 15 min"
    elif 15.0 < value <= 30.0:
        return "Diff 16-30 min"
    elif 30.0 < value <= 60.0:
        return "Diff 31-60 min"
    elif value > 60.0:
        return "Diff > 61"

flight_delay['delay_level'] = flight_delay['Delay_diff'].map(delay_level)
display(flight_delay.head())
# Out:
#    FlightDate            Airline Origin Dest  Cancelled  DepTime  DepDelay  \
# 0  2018-01-23  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 1  2018-01-24  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 2  2018-01-25  Endeavor Air Inc.    ABY  ATL      False   1153.0      -9.0
# 3  2018-01-26  Endeavor Air Inc.    ABY  ATL      False   1150.0     -12.0
# 4  2018-01-27  Endeavor Air Inc.    ABY  ATL      False   1355.0      -5.0
#
#    ArrTime  AirTime  CRSElapsedTime  ...  DayOfWeek  DepTimeBlk  ArrDelay  \
# 0   1256.0     38.0            62.0  ...          2   1200-1259      -8.0
# 1   1258.0     36.0            62.0  ...          3   1200-1259      -6.0
# 2   1302.0     40.0            62.0  ...          4   1200-1259      -2.0
# 3   1253.0     35.0            62.0  ...          5   1200-1259     -11.0
# 4   1459.0     36.0            60.0  ...          6   1400-1459      -1.0
#
#    ArrTimeBlk         Flight_Status  Distance_level Airport_DailyDep_Avg  \
# 0   1300-1359  Early Depart_On Time  Distance < 300                 1.37
# 1   1300-1359  Early Depart_On Time  Distance < 300                 1.37
# 2   1300-1359  Early Depart_On Time  Distance < 300                 1.37
# 3   1300-1359  Early Depart_On Time  Distance < 300                 1.37
# 4   1500-1559  Early Depart_On Time  Distance < 300                 1.37
#
#    Airport_Size Delay_diff    delay_level
# 0         Small       -3.0       Diff < 0
# 1         Small       -1.0       Diff < 0
# 2         Small        7.0  Diff < 15 min
# 3         Small        1.0  Diff < 15 min
# 4         Small        4.0  Diff < 15 min
#
# [5 rows x 25 columns]

# %%
# 5. DepDelay_level column:

def DepDelay_level(value):
    if value <= 0.0:
        return "Early Depart < 0"
    if 0.0 < value <= 15.0:
        return "DepDelay < 15 min"
    elif 15.0 < value <= 30.0:
        return "DepDelay 16-30 min"
    elif 30.0 < value <= 60.0:
        return "DepDelay 31-60 min"
    elif value > 60.0:
        return "DepDelay > 61"

flight_delay['DepDelay_level'] = flight_delay['DepDelay'].map(DepDelay_level)
display(flight_delay.head())
# Out:
#    FlightDate            Airline Origin Dest  Cancelled  DepTime  DepDelay  \
# 0  2018-01-23  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 1  2018-01-24  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 2  2018-01-25  Endeavor Air Inc.    ABY  ATL      False   1153.0      -9.0
# 3  2018-01-26  Endeavor Air Inc.    ABY  ATL      False   1150.0     -12.0
# 4  2018-01-27  Endeavor Air Inc.    ABY  ATL      False   1355.0      -5.0
#
#    ArrTime  AirTime  CRSElapsedTime  ...  DepTimeBlk  ArrDelay  ArrTimeBlk  \
# 0   1256.0     38.0            62.0  ...   1200-1259      -8.0   1300-1359
# 1   1258.0     36.0            62.0  ...   1200-1259      -6.0   1300-1359
# 2   1302.0     40.0            62.0  ...   1200-1259      -2.0   1300-1359
# 3   1253.0     35.0            62.0  ...   1200-1259     -11.0   1300-1359
# 4   1459.0     36.0            60.0  ...   1400-1459      -1.0   1500-1559
#
#           Flight_Status  Distance_level  Airport_DailyDep_Avg Airport_Size  \
# 0  Early Depart_On Time  Distance < 300                  1.37        Small
# 1  Early Depart_On Time  Distance < 300                  1.37        Small
# 2  Early Depart_On Time  Distance < 300                  1.37        Small
# 3  Early Depart_On Time  Distance < 300                  1.37        Small
# 4  Early Depart_On Time  Distance < 300                  1.37        Small
#
#    Delay_diff    delay_level    DepDelay_level
# 0        -3.0       Diff < 0  Early Depart < 0
# 1        -1.0       Diff < 0  Early Depart < 0
# 2         7.0  Diff < 15 min  Early Depart < 0
# 3         1.0  Diff < 15 min  Early Depart < 0
# 4         4.0  Diff < 15 min  Early Depart < 0
#
# [5 rows x 26 columns]

# %%
# 6. ArrDelay_level column:

def ArrDelay_level(value):
    if value <= 0.0:
        return "Early Arrival < 0"
    if 0.0 < value <= 15.0:
        return "ArrDelay < 15 min"
    elif 15.0 < value <= 30.0:
        return "ArrDelay 16-30 min"
    elif 30.0 < value <= 60.0:
        return "ArrDelay 31-60 min"
    elif value > 60.0:
        return "ArrDelay > 61"

flight_delay['ArrDelay_level'] = flight_delay['ArrDelay'].map(ArrDelay_level)
display(flight_delay.head())
# Out:
#    FlightDate            Airline Origin Dest  Cancelled  DepTime  DepDelay  \
# 0  2018-01-23  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 1  2018-01-24  Endeavor Air Inc.    ABY  ATL      False   1157.0      -5.0
# 2  2018-01-25  Endeavor Air Inc.    ABY  ATL      False   1153.0      -9.0
# 3  2018-01-26  Endeavor Air Inc.    ABY  ATL      False   1150.0     -12.0
# 4  2018-01-27  Endeavor Air Inc.    ABY  ATL      False   1355.0      -5.0
#
#    ArrTime  AirTime  CRSElapsedTime  ...  ArrDelay  ArrTimeBlk  \
# 0   1256.0     38.0            62.0  ...      -8.0   1300-1359
# 1   1258.0     36.0            62.0  ...      -6.0   1300-1359
# 2   1302.0     40.0            62.0  ...      -2.0   1300-1359
# 3   1253.0     35.0            62.0  ...     -11.0   1300-1359
# 4   1459.0     36.0            60.0  ...      -1.0   1500-1559
#
#           Flight_Status  Distance_level  Airport_DailyDep_Avg  Airport_Size  \
# 0  Early Depart_On Time  Distance < 300                  1.37         Small
# 1  Early Depart_On Time  Distance < 300                  1.37         Small
# 2  Early Depart_On Time  Distance < 300                  1.37         Small
# 3  Early Depart_On Time  Distance < 300                  1.37         Small
# 4  Early Depart_On Time  Distance < 300                  1.37         Small
#
#   Delay_diff    delay_level    DepDelay_level     ArrDelay_level
# 0       -3.0       Diff < 0  Early Depart < 0  Early Arrival < 0
# 1       -1.0       Diff < 0  Early Depart < 0  Early Arrival < 0
# 2        7.0  Diff < 15 min  Early Depart < 0  Early Arrival < 0
# 3        1.0  Diff < 15 min  Early Depart < 0  Early Arrival < 0
# 4        4.0  Diff < 15 min  Early Depart < 0  Early Arrival < 0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Part 2: Data Exploration
#
# #### 1. DepDelay & Time Block

# %%
# Create 2 dataframe for departure delay only, and for arrival delay only
FB_Dep = flight_delay[(flight_delay['DepDelay'] > 0)]
FB_Arr = flight_delay[(flight_delay['ArrDelay'] > 0)]

# %%
# For all the flights:
plt.figure(figsize=(20,5))
flight_delay.groupby(['DepTimeBlk'])['DepDelay'].mean().plot(legend = True)
flight_delay.groupby(['DepTimeBlk'])['ArrDelay'].mean().plot(legend = True)
plt.xlabel("Departure Time Block")
plt.ylabel("Average Delay min")
plt.title("The Average Departure Delay Time by Time Block")
# Out:
# Text(0.5, 1.0, 'The Average Departure Delay Time by Time Block')

# %%
# For delay flights:
plt.figure(figsize=(20,5))
FB_Dep.groupby(['DepTimeBlk'])['DepDelay'].mean().plot(legend = True)
FB_Arr.groupby(['DepTimeBlk'])['ArrDelay'].mean().plot(legend = True)
plt.xlabel("Departure Time Block")
plt.ylabel("Average Delay min")
plt.title("The Average Departure Delay Time by Time Block for DepDelay flights")
# Out:
# Text(0.5, 1.0, 'The Average Departure Delay Time by Time Block for DepDelay flights')

# %% [markdown]
# #### 2. Departure Delay Rate by Time Block:

# %%
# save the delay counts and the total flight counts into dataframe 
del_num = FB_Dep.groupby(['DepTimeBlk'])['DepDelay_level'].count().to_frame()
total_num = flight_delay.groupby(['DepTimeBlk'])['DepDelay_level'].count().to_frame()

# %%
# Create a table include delay counts and total flights count to calculate the delay rate 
join_tab = (pd.concat([del_num, total_num], axis = 1))
join_tab.columns = ["Delay Counts","Total Counts"]
join_tab['Rate'] = (join_tab['Delay Counts'] / join_tab['Total Counts']) * 100
join_tab['Rate'].plot(kind='bar', alpha = 0.5,title = 'Flight Delay Rate by Time Block', figsize = (15,5))
plt.xlabel("Departure Time Block")
plt.ylabel("Delay Rate")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# #### 3. Quarter

# %%
# For delay flights:
plt.figure(figsize=(20,5))
FB_Dep.groupby(['Quarter'])['DepDelay'].count().plot(legend = True)
FB_Arr.groupby(['Quarter'])['ArrDelay'].count().plot(legend = True)
plt.title("The Departure Delay Count and Arrival Delay Count by Quarter")
# Out:
# Text(0.5, 1.0, 'The Departure Delay Count and Arrival Delay Count by Quarter')

# %%
# save the delay counts by quarter and the total flight counts by quarter into dataframe 
quarter_delay = FB_Dep.groupby(['Quarter'])['DepDelay'].count().to_frame()
quarter_tt = flight.groupby(['Quarter'])['DepDelay'].count().to_frame()

# %%
# Create a table include delay counts by quarter and total flights count by quarter to calculate the delay rate 
quarter_tab = (pd.concat([quarter_delay, quarter_tt], axis = 1))
quarter_tab.columns = ["quarter_delay Counts","quarter_tt Counts"]
quarter_tab['Rate'] = (quarter_tab['quarter_delay Counts'] / quarter_tab['quarter_tt Counts']) * 100
quarter_tab['Rate'].plot(kind='bar',alpha = 0.5, title = 'Flight Departure Delay Rate by quarter', figsize = (15,5))
plt.xlabel("Quarter")
plt.ylabel("Delay Rate")
plt.xticks(rotation = 360)
plt.show()

# %% [markdown]
# #### 4. Month

# %%
Month_delay = FB_Dep.groupby(['Month'])['DepDelay'].count().to_frame()
Month_tt = flight.groupby(['Month'])['DepDelay'].count().to_frame()

# %%
Month_tab = (pd.concat([Month_delay, Month_tt], axis = 1))
Month_tab.columns = ["Month_delay Counts","Month_tt Counts"]
Month_tab['Rate'] = (Month_tab['Month_delay Counts'] / Month_tab['Month_tt Counts']) * 100
Month_tab['Rate'].plot(kind='bar', alpha = 0.5,title = 'Flight Departure Delay Rate by Month', figsize = (15,5))
plt.xlabel("Month")
plt.ylabel("Delay Rate")
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# #### 5. Day of the Week

# %%
DoW_delay = FB_Dep.groupby(['DayOfWeek'])['DepDelay'].count().to_frame()
DoW_tt = flight.groupby(['DayOfWeek'])['DepDelay'].count().to_frame()

# %%
DoW_tab = (pd.concat([Month_delay, DoW_tt], axis = 1))
DoW_tab.columns = ["DoW_delay Counts","DoW_tt Counts"]
DoW_tab['Rate'] = (DoW_tab['DoW_delay Counts'] / DoW_tab['DoW_tt Counts']) * 100
DoW_tab['Rate'].plot(kind='bar', alpha = 0.5,title = 'Flight Departure Delay Rate by Day of the Week', figsize = (15,5))
plt.xlabel("Day of the Week")
plt.ylabel("Delay Rate")
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# #### 6. Day of the Month

# %%
DoM_delay = FB_Dep.groupby(['DayofMonth'])['DepDelay'].count().to_frame()
DoM_tt = flight.groupby(['DayofMonth'])['DepDelay'].count().to_frame()
DoM_tab = (pd.concat([DoM_delay, DoM_tt], axis = 1))
DoM_tab.columns = ["DoM_delay Counts","DoM_tt Counts"]
DoM_tab['Rate'] = (DoM_tab['DoM_delay Counts'] / DoM_tab['DoM_tt Counts']) * 100

# %%
DoM_tab['Rate'].plot(kind='bar', alpha = 0.5,title = 'Flight Departure Delay Rate by Day of the Month', figsize = (15,5))
plt.xlabel("Day of the Month")
plt.ylabel("Delay Rate")
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# #### 7. Flights number counts by Time Referrence

# %%
# flight counts by Quarter, month, day of the month and day of the week:
n_bins = 10
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2, ncols=2)

ax0.hist(flight['Quarter'], n_bins, density=True, histtype='bar', stacked = True)
ax0.set_title('Quarter')

ax1.hist(flight['Month'], n_bins, density=True, histtype='bar', stacked=True)
ax1.set_title('Month')

ax2.hist(flight['DayofMonth'], n_bins, histtype='bar', stacked=True)
ax2.set_title('Day of Month')

ax3.hist(flight['DayOfWeek'], n_bins, histtype='bar', stacked=True)
ax3.set_title('Day of Week')

fig.tight_layout()
plt.show()

# %% [markdown]
# #### 8. Distance

# %%
# plot the histogram of the flights by distance
plt.figure(figsize = (10,5))
plt.hist(flight['Distance'], alpha = 0.5, label='Distance')
plt.legend(loc='upper right')
plt.xlabel("Flight Distance")
plt.ylabel("Counts")
plt.ticklabel_format(style='plain')
plt.title('Flight Distance and Counts')
plt.show()

# %% [markdown]
# #### 9. AirTime & RSElapsedTime & ActualElapsedTime

# %%
# Create a overlap histogram of the AirTime, CRSElapsedTime, ActualElapsedTime
plt.figure(figsize = (10,5))
plt.hist(flight_delay['AirTime'], alpha = 0.5, label='AirTime')
plt.hist(flight_delay['CRSElapsedTime'], alpha = 0.5, label='CRSElapsedTime')
plt.hist(flight_delay['ActualElapsedTime'], alpha = 0.5, label='ActualElapsedTime')
plt.legend(loc='upper right')
plt.title('Overlapping of AirTime, CRSElaspsedTime and ActualElaspedTime')
plt.show()

# %% [markdown]
# #### 10. Delay ( Departure Delay & Arrival Delay)

# %%
# Create a new dataframe to include the all departure delay and arrival delay data
Delay = flight_delay[((flight_delay['DepDelay'] > 0) | (flight_delay['ArrDelay'] > 0))]

# %%
# Plot the departure delay counts by different departure delay level
DepDelay_fig = Delay['DepDelay_level'].value_counts().to_frame()
DepDelay_fig.plot(kind='bar',alpha = 0.5, title = 'Departure Deley Level', figsize = (15,5))
plt.xticks(rotation =45)
plt.show()

# %%
# DepDelay_level and ArrDelay_level percentage table:
delay_table = pd.crosstab(Delay['DepDelay_level'], 
                            Delay['ArrDelay_level'],
                               normalize='index').round(4)*100
delay_table.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_ee8dc_row0_col0, #T_ee8dc_row1_col1, #T_ee8dc_row2_col4, #T_ee8dc_row3_col3, #T_ee8dc_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ee8dc_row0_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_ee8dc_row0_col2 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_ee8dc_row0_col3 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_ee8dc_row0_col4, #T_ee8dc_row3_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_ee8dc_row1_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_ee8dc_row1_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_ee8dc_row1_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_ee8dc_row1_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_ee8dc_row2_col0 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_ee8dc_row2_col1, #T_ee8dc_row2_col3, #T_ee8dc_row3_col0, #T_ee8dc_row3_col2, #T_ee8dc_row3_col4, #T_ee8dc_row4_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ee8dc_row2_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_ee8dc_row4_col0 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_ee8dc_row4_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ee8dc_row4_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_ee8dc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >ArrDelay_level</th>
#       <th id="T_ee8dc_level0_col0" class="col_heading level0 col0" >ArrDelay 16-30 min</th>
#       <th id="T_ee8dc_level0_col1" class="col_heading level0 col1" >ArrDelay 31-60 min</th>
#       <th id="T_ee8dc_level0_col2" class="col_heading level0 col2" >ArrDelay < 15 min</th>
#       <th id="T_ee8dc_level0_col3" class="col_heading level0 col3" >ArrDelay > 61</th>
#       <th id="T_ee8dc_level0_col4" class="col_heading level0 col4" >Early Arrival < 0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DepDelay_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee8dc_level0_row0" class="row_heading level0 row0" >DepDelay 16-30 min</th>
#       <td id="T_ee8dc_row0_col0" class="data row0 col0" >36.630000</td>
#       <td id="T_ee8dc_row0_col1" class="data row0 col1" >12.490000</td>
#       <td id="T_ee8dc_row0_col2" class="data row0 col2" >40.470000</td>
#       <td id="T_ee8dc_row0_col3" class="data row0 col3" >1.640000</td>
#       <td id="T_ee8dc_row0_col4" class="data row0 col4" >8.770000</td>
#     </tr>
#     <tr>
#       <th id="T_ee8dc_level0_row1" class="row_heading level0 row1" >DepDelay 31-60 min</th>
#       <td id="T_ee8dc_row1_col0" class="data row1 col0" >26.920000</td>
#       <td id="T_ee8dc_row1_col1" class="data row1 col1" >57.550000</td>
#       <td id="T_ee8dc_row1_col2" class="data row1 col2" >5.270000</td>
#       <td id="T_ee8dc_row1_col3" class="data row1 col3" >9.750000</td>
#       <td id="T_ee8dc_row1_col4" class="data row1 col4" >0.510000</td>
#     </tr>
#     <tr>
#       <th id="T_ee8dc_level0_row2" class="row_heading level0 row2" >DepDelay < 15 min</th>
#       <td id="T_ee8dc_row2_col0" class="data row2 col0" >8.540000</td>
#       <td id="T_ee8dc_row2_col1" class="data row2 col1" >2.650000</td>
#       <td id="T_ee8dc_row2_col2" class="data row2 col2" >36.860000</td>
#       <td id="T_ee8dc_row2_col3" class="data row2 col3" >0.450000</td>
#       <td id="T_ee8dc_row2_col4" class="data row2 col4" >51.500000</td>
#     </tr>
#     <tr>
#       <th id="T_ee8dc_level0_row3" class="row_heading level0 row3" >DepDelay > 61</th>
#       <td id="T_ee8dc_row3_col0" class="data row3 col0" >0.200000</td>
#       <td id="T_ee8dc_row3_col1" class="data row3 col1" >11.940000</td>
#       <td id="T_ee8dc_row3_col2" class="data row3 col2" >0.020000</td>
#       <td id="T_ee8dc_row3_col3" class="data row3 col3" >87.840000</td>
#       <td id="T_ee8dc_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ee8dc_level0_row4" class="row_heading level0 row4" >Early Depart < 0</th>
#       <td id="T_ee8dc_row4_col0" class="data row4 col0" >14.950000</td>
#       <td id="T_ee8dc_row4_col1" class="data row4 col1" >5.010000</td>
#       <td id="T_ee8dc_row4_col2" class="data row4 col2" >79.080000</td>
#       <td id="T_ee8dc_row4_col3" class="data row4 col3" >0.960000</td>
#       <td id="T_ee8dc_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Departure Delay only:

# %%
# create a new datafram for departure delay flights only
Dep_Delay = Delay[Delay['DepDelay'] > 0.0 ]

# %%
# For DepDelay data only: DepDelay_level and ArrDelay_level percentage table:
Dep_delay_table = pd.crosstab(Dep_Delay['DepDelay_level'], 
                            Dep_Delay['ArrDelay_level'],
                               normalize='index').round(4)*100
Dep_delay_table.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_60c86_row0_col0, #T_60c86_row0_col2, #T_60c86_row1_col1, #T_60c86_row2_col4, #T_60c86_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_60c86_row0_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_60c86_row0_col3 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_60c86_row0_col4, #T_60c86_row3_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_60c86_row1_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_60c86_row1_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_60c86_row1_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_60c86_row1_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_60c86_row2_col0 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_60c86_row2_col1, #T_60c86_row2_col3, #T_60c86_row3_col0, #T_60c86_row3_col2, #T_60c86_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_60c86_row2_col2 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_60c86">
#   <thead>
#     <tr>
#       <th class="index_name level0" >ArrDelay_level</th>
#       <th id="T_60c86_level0_col0" class="col_heading level0 col0" >ArrDelay 16-30 min</th>
#       <th id="T_60c86_level0_col1" class="col_heading level0 col1" >ArrDelay 31-60 min</th>
#       <th id="T_60c86_level0_col2" class="col_heading level0 col2" >ArrDelay < 15 min</th>
#       <th id="T_60c86_level0_col3" class="col_heading level0 col3" >ArrDelay > 61</th>
#       <th id="T_60c86_level0_col4" class="col_heading level0 col4" >Early Arrival < 0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DepDelay_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60c86_level0_row0" class="row_heading level0 row0" >DepDelay 16-30 min</th>
#       <td id="T_60c86_row0_col0" class="data row0 col0" >36.630000</td>
#       <td id="T_60c86_row0_col1" class="data row0 col1" >12.490000</td>
#       <td id="T_60c86_row0_col2" class="data row0 col2" >40.470000</td>
#       <td id="T_60c86_row0_col3" class="data row0 col3" >1.640000</td>
#       <td id="T_60c86_row0_col4" class="data row0 col4" >8.770000</td>
#     </tr>
#     <tr>
#       <th id="T_60c86_level0_row1" class="row_heading level0 row1" >DepDelay 31-60 min</th>
#       <td id="T_60c86_row1_col0" class="data row1 col0" >26.920000</td>
#       <td id="T_60c86_row1_col1" class="data row1 col1" >57.550000</td>
#       <td id="T_60c86_row1_col2" class="data row1 col2" >5.270000</td>
#       <td id="T_60c86_row1_col3" class="data row1 col3" >9.750000</td>
#       <td id="T_60c86_row1_col4" class="data row1 col4" >0.510000</td>
#     </tr>
#     <tr>
#       <th id="T_60c86_level0_row2" class="row_heading level0 row2" >DepDelay < 15 min</th>
#       <td id="T_60c86_row2_col0" class="data row2 col0" >8.540000</td>
#       <td id="T_60c86_row2_col1" class="data row2 col1" >2.650000</td>
#       <td id="T_60c86_row2_col2" class="data row2 col2" >36.860000</td>
#       <td id="T_60c86_row2_col3" class="data row2 col3" >0.450000</td>
#       <td id="T_60c86_row2_col4" class="data row2 col4" >51.500000</td>
#     </tr>
#     <tr>
#       <th id="T_60c86_level0_row3" class="row_heading level0 row3" >DepDelay > 61</th>
#       <td id="T_60c86_row3_col0" class="data row3 col0" >0.200000</td>
#       <td id="T_60c86_row3_col1" class="data row3 col1" >11.940000</td>
#       <td id="T_60c86_row3_col2" class="data row3 col2" >0.020000</td>
#       <td id="T_60c86_row3_col3" class="data row3 col3" >87.840000</td>
#       <td id="T_60c86_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# create a new datafram for arrival delay flights only
Arr_Delay = Delay[Delay['ArrDelay'] > 0.0 ]

# %%
# For ArrDelay data only: DepDelay_level and ArrDelay_level percentage table:
Arr_delay_table = pd.crosstab(Arr_Delay['ArrDelay_level'],
                              Arr_Delay['DepDelay_level'], 
                               normalize='index').round(4)*100
Arr_delay_table.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_c4b17_row0_col0, #T_c4b17_row1_col1, #T_c4b17_row2_col2, #T_c4b17_row2_col4, #T_c4b17_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c4b17_row0_col1 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_c4b17_row0_col2 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_c4b17_row0_col3, #T_c4b17_row2_col1, #T_c4b17_row2_col3, #T_c4b17_row3_col0, #T_c4b17_row3_col2, #T_c4b17_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c4b17_row0_col4 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_c4b17_row1_col0 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_c4b17_row1_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c4b17_row1_col3 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_c4b17_row1_col4 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_c4b17_row2_col0 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_c4b17_row3_col1 {
#   background-color: #deebf7;
#   color: #000000;
# }
# </style>
# <table id="T_c4b17">
#   <thead>
#     <tr>
#       <th class="index_name level0" >DepDelay_level</th>
#       <th id="T_c4b17_level0_col0" class="col_heading level0 col0" >DepDelay 16-30 min</th>
#       <th id="T_c4b17_level0_col1" class="col_heading level0 col1" >DepDelay 31-60 min</th>
#       <th id="T_c4b17_level0_col2" class="col_heading level0 col2" >DepDelay < 15 min</th>
#       <th id="T_c4b17_level0_col3" class="col_heading level0 col3" >DepDelay > 61</th>
#       <th id="T_c4b17_level0_col4" class="col_heading level0 col4" >Early Depart < 0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ArrDelay_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4b17_level0_row0" class="row_heading level0 row0" >ArrDelay 16-30 min</th>
#       <td id="T_c4b17_row0_col0" class="data row0 col0" >33.960000</td>
#       <td id="T_c4b17_row0_col1" class="data row0 col1" >21.990000</td>
#       <td id="T_c4b17_row0_col2" class="data row0 col2" >21.070000</td>
#       <td id="T_c4b17_row0_col3" class="data row0 col3" >0.180000</td>
#       <td id="T_c4b17_row0_col4" class="data row0 col4" >22.800000</td>
#     </tr>
#     <tr>
#       <th id="T_c4b17_level0_row1" class="row_heading level0 row1" >ArrDelay 31-60 min</th>
#       <td id="T_c4b17_row1_col0" class="data row1 col0" >13.820000</td>
#       <td id="T_c4b17_row1_col1" class="data row1 col1" >56.060000</td>
#       <td id="T_c4b17_row1_col2" class="data row1 col2" >7.800000</td>
#       <td id="T_c4b17_row1_col3" class="data row1 col3" >13.200000</td>
#       <td id="T_c4b17_row1_col4" class="data row1 col4" >9.120000</td>
#     </tr>
#     <tr>
#       <th id="T_c4b17_level0_row2" class="row_heading level0 row2" >ArrDelay < 15 min</th>
#       <td id="T_c4b17_row2_col0" class="data row2 col0" >14.800000</td>
#       <td id="T_c4b17_row2_col1" class="data row2 col1" >1.700000</td>
#       <td id="T_c4b17_row2_col2" class="data row2 col2" >35.890000</td>
#       <td id="T_c4b17_row2_col3" class="data row2 col3" >0.010000</td>
#       <td id="T_c4b17_row2_col4" class="data row2 col4" >47.600000</td>
#     </tr>
#     <tr>
#       <th id="T_c4b17_level0_row3" class="row_heading level0 row3" >ArrDelay > 61</th>
#       <td id="T_c4b17_row3_col0" class="data row3 col0" >1.630000</td>
#       <td id="T_c4b17_row3_col1" class="data row3 col1" >8.520000</td>
#       <td id="T_c4b17_row3_col2" class="data row3 col2" >1.190000</td>
#       <td id="T_c4b17_row3_col3" class="data row3 col3" >87.100000</td>
#       <td id="T_c4b17_row3_col4" class="data row3 col4" >1.570000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# for DepDelay datagroup, "DepDelay < 15 min" has 51.5% of flights can "Early Arrival < 0"
Dep15 = Dep_Delay[Dep_Delay['DepDelay_level'] == 'DepDelay < 15 min']

# %%
Distance1 = Dep15[Dep15['ArrDelay_level'] == 'Early Arrival < 0']

# %%
# keep track of the flight distance
Dep15EarlyArr = (pd.DataFrame(Distance1['Distance_level'].value_counts().to_frame())).join(
([pd.DataFrame(Distance1.groupby(['Distance_level'])['DepDelay'].mean()), 
 pd.DataFrame(Distance1.groupby(['Distance_level'])['ArrDelay'].mean().to_frame())]))
Dep15EarlyArr.columns = ['Flight_counts', 'Avg_DepDelay min', 'Avg_ArrDelay min']
Dep15EarlyArr.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_04d53_row0_col0, #T_04d53_row3_col2, #T_04d53_row6_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_04d53_row0_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_04d53_row0_col2 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_04d53_row1_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_04d53_row1_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_04d53_row1_col2 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_04d53_row2_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_04d53_row2_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_04d53_row2_col2 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_04d53_row3_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_04d53_row3_col1, #T_04d53_row6_col2, #T_04d53_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_04d53_row4_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_04d53_row4_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_04d53_row4_col2 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_04d53_row5_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_04d53_row5_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_04d53_row5_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_04d53_row6_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_04d53_row7_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_04d53_row7_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_04d53_row7_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_04d53_row8_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_04d53_row8_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_04d53_row8_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_04d53_row9_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_04d53_row9_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# </style>
# <table id="T_04d53">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04d53_level0_col0" class="col_heading level0 col0" >Flight_counts</th>
#       <th id="T_04d53_level0_col1" class="col_heading level0 col1" >Avg_DepDelay min</th>
#       <th id="T_04d53_level0_col2" class="col_heading level0 col2" >Avg_ArrDelay min</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04d53_level0_row0" class="row_heading level0 row0" >Distance 300-600 mile</th>
#       <td id="T_04d53_row0_col0" class="data row0 col0" >122183</td>
#       <td id="T_04d53_row0_col1" class="data row0 col1" >4.744375</td>
#       <td id="T_04d53_row0_col2" class="data row0 col2" >-6.249274</td>
#     </tr>
#     <tr>
#       <th id="T_04d53_level0_row1" class="row_heading level0 row1" >Distance 600-900 mile</th>
#       <td id="T_04d53_row1_col0" class="data row1 col0" >99231</td>
#       <td id="T_04d53_row1_col1" class="data row1 col1" >5.098104</td>
#       <td id="T_04d53_row1_col2" class="data row1 col2" >-7.705818</td>
#     </tr>
#     <tr>
#       <th id="T_04d53_level0_row2" class="row_heading level0 row2" >Distance 900-1200 mile</th>
#       <td id="T_04d53_row2_col0" class="data row2 col0" >81472</td>
#       <td id="T_04d53_row2_col1" class="data row2 col1" >5.315998</td>
#       <td id="T_04d53_row2_col2" class="data row2 col2" >-8.817876</td>
#     </tr>
#     <tr>
#       <th id="T_04d53_level0_row3" class="row_heading level0 row3" >Distance < 300</th>
#       <td id="T_04d53_row3_col0" class="data row3 col0" >59909</td>
#       <td id="T_04d53_row3_col1" class="data row3 col1" >4.682034</td>
#       <td id="T_04d53_row3_col2" class="data row3 col2" >-5.944516</td>
#     </tr>
#     <tr>
#       <th id="T_04d53_level0_row4" class="row_heading level0 row4" >Distance 1200-1500 mile</th>
#       <td id="T_04d53_row4_col0" class="data row4 col0" >35710</td>
#       <td id="T_04d53_row4_col1" class="data row4 col1" >5.385690</td>
#       <td id="T_04d53_row4_col2" class="data row4 col2" >-10.021395</td>
#     </tr>
#     <tr>
#       <th id="T_04d53_level0_row5" class="row_heading level0 row5" >Distance 1500-1800 mile</th>
#       <td id="T_04d53_row5_col0" class="data row5 col0" >33938</td>
#       <td id="T_04d53_row5_col1" class="data row5 col1" >5.411780</td>
#       <td id="T_04d53_row5_col2" class="data row5 col2" >-10.970181</td>
#     </tr>
#     <tr>
#       <th id="T_04d53_level0_row6" class="row_heading level0 row6" >Distance 2400-2700 mile</th>
#       <td id="T_04d53_row6_col0" class="data row6 col0" >15605</td>
#       <td id="T_04d53_row6_col1" class="data row6 col1" >5.511246</td>
#       <td id="T_04d53_row6_col2" class="data row6 col2" >-13.176546</td>
#     </tr>
#     <tr>
#       <th id="T_04d53_level0_row7" class="row_heading level0 row7" >Distance 1800-2100 mile</th>
#       <td id="T_04d53_row7_col0" class="data row7 col0" >15182</td>
#       <td id="T_04d53_row7_col1" class="data row7 col1" >5.506982</td>
#       <td id="T_04d53_row7_col2" class="data row7 col2" >-11.415821</td>
#     </tr>
#     <tr>
#       <th id="T_04d53_level0_row8" class="row_heading level0 row8" >Distance 2100-2400 mile</th>
#       <td id="T_04d53_row8_col0" class="data row8 col0" >14618</td>
#       <td id="T_04d53_row8_col1" class="data row8 col1" >5.489602</td>
#       <td id="T_04d53_row8_col2" class="data row8 col2" >-12.384389</td>
#     </tr>
#     <tr>
#       <th id="T_04d53_level0_row9" class="row_heading level0 row9" >Distance > 2700 mile</th>
#       <td id="T_04d53_row9_col0" class="data row9 col0" >2943</td>
#       <td id="T_04d53_row9_col1" class="data row9 col1" >5.504247</td>
#       <td id="T_04d53_row9_col2" class="data row9 col2" >-12.791030</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(20,5))
Distance_fig1 = sns.histplot(Distance1["Distance_level"])
plt.title("Departure Delay < 15 min but Arrive Before Schedule's Flight Record Bar Graph by Flight Distance")
plt.xticks(rotation = 45)
plt.show()

# %%
# for DepDelay datagroup, "DepDelay 16 - 30 min", has 40.5% chance can "ArrDelay < 15 min"
Dep30 = Dep_Delay[Dep_Delay['DepDelay_level'] == 'DepDelay 16-30 min']
Distance2 = Dep30[Dep30['ArrDelay_level'] == 'ArrDelay < 15 min']

# %%
# keep track of the flight distance
Dep30Arr15 = (pd.DataFrame(Distance2['Distance_level'].value_counts().to_frame())).join(
([Distance2.groupby(['Distance_level'])['DepDelay'].mean(), 
Distance2.groupby(['Distance_level'])['ArrDelay'].mean()]))
Dep30Arr15.columns = ['Flight_counts', 'Avg_DepDelay min', 'Avg_ArrDelay min']
Dep30Arr15.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_62213_row0_col0, #T_62213_row3_col2, #T_62213_row6_col1, #T_62213_row8_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_62213_row0_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_62213_row0_col2 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_62213_row1_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_62213_row1_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_62213_row1_col2 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_62213_row2_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_62213_row2_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_62213_row2_col2 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_62213_row3_col0 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_62213_row3_col1, #T_62213_row7_col2, #T_62213_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_62213_row4_col0 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_62213_row4_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_62213_row4_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_62213_row5_col0 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_62213_row5_col1 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_62213_row5_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_62213_row6_col0, #T_62213_row8_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_62213_row6_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_62213_row7_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_62213_row7_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_62213_row8_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_62213_row9_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_62213_row9_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# </style>
# <table id="T_62213">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62213_level0_col0" class="col_heading level0 col0" >Flight_counts</th>
#       <th id="T_62213_level0_col1" class="col_heading level0 col1" >Avg_DepDelay min</th>
#       <th id="T_62213_level0_col2" class="col_heading level0 col2" >Avg_ArrDelay min</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62213_level0_row0" class="row_heading level0 row0" >Distance 300-600 mile</th>
#       <td id="T_62213_row0_col0" class="data row0 col0" >40409</td>
#       <td id="T_62213_row0_col1" class="data row0 col1" >20.475587</td>
#       <td id="T_62213_row0_col2" class="data row0 col2" >9.660422</td>
#     </tr>
#     <tr>
#       <th id="T_62213_level0_row1" class="row_heading level0 row1" >Distance 600-900 mile</th>
#       <td id="T_62213_row1_col0" class="data row1 col0" >30433</td>
#       <td id="T_62213_row1_col1" class="data row1 col1" >21.034272</td>
#       <td id="T_62213_row1_col2" class="data row1 col2" >9.030723</td>
#     </tr>
#     <tr>
#       <th id="T_62213_level0_row2" class="row_heading level0 row2" >Distance 900-1200 mile</th>
#       <td id="T_62213_row2_col0" class="data row2 col0" >23539</td>
#       <td id="T_62213_row2_col1" class="data row2 col1" >21.304728</td>
#       <td id="T_62213_row2_col2" class="data row2 col2" >8.718595</td>
#     </tr>
#     <tr>
#       <th id="T_62213_level0_row3" class="row_heading level0 row3" >Distance < 300</th>
#       <td id="T_62213_row3_col0" class="data row3 col0" >21378</td>
#       <td id="T_62213_row3_col1" class="data row3 col1" >20.436898</td>
#       <td id="T_62213_row3_col2" class="data row3 col2" >9.813126</td>
#     </tr>
#     <tr>
#       <th id="T_62213_level0_row4" class="row_heading level0 row4" >Distance 1200-1500 mile</th>
#       <td id="T_62213_row4_col0" class="data row4 col0" >8904</td>
#       <td id="T_62213_row4_col1" class="data row4 col1" >21.506402</td>
#       <td id="T_62213_row4_col2" class="data row4 col2" >8.479447</td>
#     </tr>
#     <tr>
#       <th id="T_62213_level0_row5" class="row_heading level0 row5" >Distance 1500-1800 mile</th>
#       <td id="T_62213_row5_col0" class="data row5 col0" >7643</td>
#       <td id="T_62213_row5_col1" class="data row5 col1" >21.683370</td>
#       <td id="T_62213_row5_col2" class="data row5 col2" >8.311396</td>
#     </tr>
#     <tr>
#       <th id="T_62213_level0_row6" class="row_heading level0 row6" >Distance 1800-2100 mile</th>
#       <td id="T_62213_row6_col0" class="data row6 col0" >3201</td>
#       <td id="T_62213_row6_col1" class="data row6 col1" >21.704780</td>
#       <td id="T_62213_row6_col2" class="data row6 col2" >8.218057</td>
#     </tr>
#     <tr>
#       <th id="T_62213_level0_row7" class="row_heading level0 row7" >Distance 2400-2700 mile</th>
#       <td id="T_62213_row7_col0" class="data row7 col0" >3106</td>
#       <td id="T_62213_row7_col1" class="data row7 col1" >21.650032</td>
#       <td id="T_62213_row7_col2" class="data row7 col2" >7.977785</td>
#     </tr>
#     <tr>
#       <th id="T_62213_level0_row8" class="row_heading level0 row8" >Distance 2100-2400 mile</th>
#       <td id="T_62213_row8_col0" class="data row8 col0" >2752</td>
#       <td id="T_62213_row8_col1" class="data row8 col1" >21.701672</td>
#       <td id="T_62213_row8_col2" class="data row8 col2" >8.105015</td>
#     </tr>
#     <tr>
#       <th id="T_62213_level0_row9" class="row_heading level0 row9" >Distance > 2700 mile</th>
#       <td id="T_62213_row9_col0" class="data row9 col0" >552</td>
#       <td id="T_62213_row9_col1" class="data row9 col1" >21.605072</td>
#       <td id="T_62213_row9_col2" class="data row9 col2" >8.041667</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Thus we know if the depart delay between 16 - 30 min, it still shows the same result, but the time difference based on the distance is not that obvious.

# %%
plt.figure(figsize=(20,5))
Distance_fig1 = sns.histplot(Distance2["Distance_level"])
plt.title("Departure Delay between 16 - 30 min but Arrive Delay within 15 min Flight Record Bar Graph by Flight Distance")
plt.xticks(rotation = 45)
plt.show()

# %%
# The DepDelay > 61 has 87.84% chance to "ArrDelay > 61", let's see their distance:
Dep60 = Dep_Delay[Dep_Delay['DepDelay_level'] == 'DepDelay > 61']
Distance3 = Dep60[Dep60['ArrDelay_level'] == 'ArrDelay > 61']

# %%
# keep track of the flight distance
Dep60Arr60 = (Distance3['Distance_level'].value_counts().to_frame()).join(
([Distance3.groupby(['Distance_level'])['DepDelay'].mean(), 
Distance3.groupby(['Distance_level'])['ArrDelay'].mean()]))
Dep60Arr60.columns = ['Flight_counts', 'Avg_DepDelay min', 'Avg_ArrDelay min']
Dep60Arr60.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_dfa4b_row0_col0, #T_dfa4b_row9_col1, #T_dfa4b_row9_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_dfa4b_row0_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_dfa4b_row0_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_dfa4b_row1_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_dfa4b_row1_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_dfa4b_row1_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_dfa4b_row2_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_dfa4b_row2_col1, #T_dfa4b_row4_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_dfa4b_row2_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_dfa4b_row3_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_dfa4b_row3_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_dfa4b_row3_col2, #T_dfa4b_row4_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_dfa4b_row4_col1, #T_dfa4b_row5_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_dfa4b_row5_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_dfa4b_row5_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_dfa4b_row6_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_dfa4b_row6_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_dfa4b_row6_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_dfa4b_row7_col0, #T_dfa4b_row8_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_dfa4b_row7_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_dfa4b_row7_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_dfa4b_row8_col1, #T_dfa4b_row8_col2, #T_dfa4b_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_dfa4b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfa4b_level0_col0" class="col_heading level0 col0" >Flight_counts</th>
#       <th id="T_dfa4b_level0_col1" class="col_heading level0 col1" >Avg_DepDelay min</th>
#       <th id="T_dfa4b_level0_col2" class="col_heading level0 col2" >Avg_ArrDelay min</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfa4b_level0_row0" class="row_heading level0 row0" >Distance 300-600 mile</th>
#       <td id="T_dfa4b_row0_col0" class="data row0 col0" >86230</td>
#       <td id="T_dfa4b_row0_col1" class="data row0 col1" >142.162971</td>
#       <td id="T_dfa4b_row0_col2" class="data row0 col2" >141.534802</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4b_level0_row1" class="row_heading level0 row1" >Distance 600-900 mile</th>
#       <td id="T_dfa4b_row1_col0" class="data row1 col0" >63562</td>
#       <td id="T_dfa4b_row1_col1" class="data row1 col1" >144.270366</td>
#       <td id="T_dfa4b_row1_col2" class="data row1 col2" >143.216670</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4b_level0_row2" class="row_heading level0 row2" >Distance < 300</th>
#       <td id="T_dfa4b_row2_col0" class="data row2 col0" >58886</td>
#       <td id="T_dfa4b_row2_col1" class="data row2 col1" >148.746833</td>
#       <td id="T_dfa4b_row2_col2" class="data row2 col2" >148.818955</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4b_level0_row3" class="row_heading level0 row3" >Distance 900-1200 mile</th>
#       <td id="T_dfa4b_row3_col0" class="data row3 col0" >49911</td>
#       <td id="T_dfa4b_row3_col1" class="data row3 col1" >145.931738</td>
#       <td id="T_dfa4b_row3_col2" class="data row3 col2" >143.938911</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4b_level0_row4" class="row_heading level0 row4" >Distance 1200-1500 mile</th>
#       <td id="T_dfa4b_row4_col0" class="data row4 col0" >16071</td>
#       <td id="T_dfa4b_row4_col1" class="data row4 col1" >147.162653</td>
#       <td id="T_dfa4b_row4_col2" class="data row4 col2" >144.013440</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4b_level0_row5" class="row_heading level0 row5" >Distance 1500-1800 mile</th>
#       <td id="T_dfa4b_row5_col0" class="data row5 col0" >13154</td>
#       <td id="T_dfa4b_row5_col1" class="data row5 col1" >142.467842</td>
#       <td id="T_dfa4b_row5_col2" class="data row5 col2" >139.015205</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4b_level0_row6" class="row_heading level0 row6" >Distance 2400-2700 mile</th>
#       <td id="T_dfa4b_row6_col0" class="data row6 col0" >8092</td>
#       <td id="T_dfa4b_row6_col1" class="data row6 col1" >153.311172</td>
#       <td id="T_dfa4b_row6_col2" class="data row6 col2" >149.922269</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4b_level0_row7" class="row_heading level0 row7" >Distance 2100-2400 mile</th>
#       <td id="T_dfa4b_row7_col0" class="data row7 col0" >5458</td>
#       <td id="T_dfa4b_row7_col1" class="data row7 col1" >149.825944</td>
#       <td id="T_dfa4b_row7_col2" class="data row7 col2" >145.118542</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4b_level0_row8" class="row_heading level0 row8" >Distance 1800-2100 mile</th>
#       <td id="T_dfa4b_row8_col0" class="data row8 col0" >5167</td>
#       <td id="T_dfa4b_row8_col1" class="data row8 col1" >141.982582</td>
#       <td id="T_dfa4b_row8_col2" class="data row8 col2" >137.553706</td>
#     </tr>
#     <tr>
#       <th id="T_dfa4b_level0_row9" class="row_heading level0 row9" >Distance > 2700 mile</th>
#       <td id="T_dfa4b_row9_col0" class="data row9 col0" >1321</td>
#       <td id="T_dfa4b_row9_col1" class="data row9 col1" >179.829674</td>
#       <td id="T_dfa4b_row9_col2" class="data row9 col2" >174.101438</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 10. Airline

# %%
# group the flight delay and total counts by airline, and calculate the delay rate of each airline
Airline_Delay = FB_Dep.groupby(['Airline'])['DepDelay'].count().to_frame()
Airline_Total = flight_delay.groupby(['Airline'])['DepDelay'].count().to_frame()
Airline_tab = (pd.concat([Airline_Delay, Airline_Total], axis = 1))
Airline_tab.columns = ["Airline_delay Counts","Airline_Total Counts"]
Airline_tab['Rate'] = (Airline_tab['Airline_delay Counts'] / Airline_tab['Airline_Total Counts']) * 100
Airline_tab = Airline_tab.sort_values( "Rate", ascending = False)
Airline_tab.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_ff611_row0_col0, #T_ff611_row0_col1, #T_ff611_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ff611_row1_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_ff611_row1_col1, #T_ff611_row21_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_ff611_row1_col2 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_ff611_row2_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_ff611_row2_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_ff611_row2_col2 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_ff611_row3_col0, #T_ff611_row3_col1, #T_ff611_row5_col0, #T_ff611_row5_col1, #T_ff611_row27_col0, #T_ff611_row27_col1, #T_ff611_row27_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ff611_row3_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_ff611_row4_col0, #T_ff611_row20_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_ff611_row4_col1, #T_ff611_row18_col1, #T_ff611_row19_col0, #T_ff611_row24_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_ff611_row4_col2 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_ff611_row5_col2 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_ff611_row6_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_ff611_row6_col1 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_ff611_row6_col2 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_ff611_row7_col0, #T_ff611_row11_col1, #T_ff611_row20_col1, #T_ff611_row21_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ff611_row7_col1, #T_ff611_row23_col0, #T_ff611_row25_col1, #T_ff611_row26_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_ff611_row7_col2 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_ff611_row8_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_ff611_row8_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_ff611_row8_col2 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_ff611_row9_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_ff611_row9_col1, #T_ff611_row11_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_ff611_row9_col2 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_ff611_row10_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_ff611_row10_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_ff611_row10_col2, #T_ff611_row12_col1 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_ff611_row11_col2 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_ff611_row12_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_ff611_row12_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_ff611_row13_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_ff611_row13_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_ff611_row13_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_ff611_row14_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_ff611_row14_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_ff611_row14_col2 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_ff611_row15_col0 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_ff611_row15_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_ff611_row15_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_ff611_row16_col0, #T_ff611_row19_col1, #T_ff611_row24_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_ff611_row16_col1 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_ff611_row16_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_ff611_row17_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_ff611_row17_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_ff611_row17_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_ff611_row18_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_ff611_row18_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_ff611_row19_col2, #T_ff611_row20_col2 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_ff611_row21_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_ff611_row22_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_ff611_row22_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_ff611_row22_col2, #T_ff611_row23_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_ff611_row23_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_ff611_row24_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_ff611_row25_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_ff611_row25_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_ff611_row26_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_ff611_row26_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# </style>
# <table id="T_ff611">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff611_level0_col0" class="col_heading level0 col0" >Airline_delay Counts</th>
#       <th id="T_ff611_level0_col1" class="col_heading level0 col1" >Airline_Total Counts</th>
#       <th id="T_ff611_level0_col2" class="col_heading level0 col2" >Rate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Airline</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff611_level0_row0" class="row_heading level0 row0" >Southwest Airlines Co.</th>
#       <td id="T_ff611_row0_col0" class="data row0 col0" >660551</td>
#       <td id="T_ff611_row0_col1" class="data row0 col1" >1331609</td>
#       <td id="T_ff611_row0_col2" class="data row0 col2" >49.605477</td>
#     </tr>
#     <tr>
#       <th id="T_ff611_level0_row1" class="row_heading level0 row1" >Frontier Airlines Inc.</th>
#       <td id="T_ff611_row1_col0" class="data row1 col0" >53187</td>
#       <td id="T_ff611_row1_col1" class="data row1 col1" >117523</td>
#       <td id="T_ff611_row1_col2" class="data row1 col2" >45.256673</td>
#     </tr>
#     <tr>
#       <th id="T_ff611_level0_row2" class="row_heading level0 row2" >JetBlue Airways</th>
#       <td id="T_ff611_row2_col0" class="data row2 col0" >124396</td>
#       <td id="T_ff611_row2_col1" class="data row2 col1" >297758</td>
#       <td id="T_ff611_row2_col2" class="data row2 col2" >41.777551</td>
#     </tr>
#     <tr>
#       <th id="T_ff611_level0_row3" class="row_heading level0 row3" >Peninsula Airways Inc.</th>
#       <td id="T_ff611_row3_col0" class="data row3 col0" >456</td>
#       <td id="T_ff611_row3_col1" class="data row3 col1" >1121</td>
#       <td id="T_ff611_row3_col2" class="data row3 col2" >40.677966</td>
#     </tr>
#     <tr>
#       <th id="T_ff611_level0_row4" class="row_heading level0 row4" >Commutair Aka Champlain Enterprises, Inc.</th>
#       <td id="T_ff611_row4_col0" class="data row4 col0" >17658</td>
#       <td id="T_ff611_row4_col1" class="data row4 col1" >45509</td>
#       <td id="T_ff611_row4_col2" class="data row4 col2" >38.801116</td>
#     </tr>
#     <tr>
#       <th id="T_ff611_level0_row5" class="row_heading level0 row5" >Empire Airlines Inc.</th>
#       <td id="T_ff611_row5_col0" class="data row5 col0" >519</td>
#       <td id="T_ff611_row5_col1" class="data row5 col1" >1411</td>
#       <td id="T_ff611_row5_col2" class="data row5 col2" >36.782424</td>
#     </tr>
#     <tr>
#       <th id="T_ff611_level0_row6" class="row_heading level0 row6" >American Airlines Inc.</th>
#       <td id="T_ff611_row6_col0" class="data row6 col0" >133816</td>
#       <td id="T_ff611_row6_col1" class="data row6 col1" >378722</td>
#       <td id="T_ff611_row6_col2" class="data row6 col2" >35.333569</td>
#     </tr>
#     <tr>
#       <th id="T_ff611_level0_row7" class="row_heading level0 row7" >Allegiant Air</th>
#       <td id="T_ff611_row7_col0" class="data row7 col0" >32787</td>
#       <td id="T_ff611_row7_col1" class="data row7 col1" >95192</td>
#       <td id="T_ff611_row7_col2" class="data row7 col2" >34.443020</td>
#     </tr>
#     <tr>
#       <th id="T_ff611_level0_row8" class="row_heading level0 row8" >Comair Inc.</th>
#       <td id="T_ff611_row8

# %%
col_order = ["Early Depart_On Time", "DepDelay < 15 min", "DepDelay 16-30 min", "DepDelay 31-60 min","DepDelay > 61", "Cancelled"]
status = flight[['Airline','Flight_Status']]
status = (status.groupby(["Airline"])["Flight_Status"].value_counts(normalize=True).unstack()[col_order])
status.sort_values("Early Depart_On Time").plot(
    kind="barh", stacked=True, width=0.8, edgecolor="black", figsize = (20,15))
plt.title("Flight Status by Airline")     
plt.xlabel("Percentage of Flight Status")
plt.ylabel("Airline")
plt.show()

# %% [markdown]
# #### 11. Airport Size

# %%
# group the flight delay and total counts by Airport_Size, and calculate the delay rate 
Origin_Delay = FB_Dep.groupby(['Airport_Size'])['DepDelay'].count().to_frame()
Origin_Total = flight_delay.groupby(['Airport_Size'])['DepDelay'].count().to_frame()
Airport_tab = (pd.concat([Origin_Delay, Origin_Total], axis = 1))
Airport_tab.columns = ["Origin_Delay Counts","Origin_Total Counts"]
Airport_tab['Rate'] = (Airport_tab['Origin_Delay Counts'] / Airport_tab['Origin_Total Counts']) * 100
Airport_tab = Airport_tab.sort_values("Rate", ascending = False).head(50)
Airport_tab.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_96ff3_row0_col0, #T_96ff3_row0_col1, #T_96ff3_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_96ff3_row1_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_96ff3_row1_col1, #T_96ff3_row2_col0, #T_96ff3_row2_col1, #T_96ff3_row2_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_96ff3_row1_col2 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_96ff3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96ff3_level0_col0" class="col_heading level0 col0" >Origin_Delay Counts</th>
#       <th id="T_96ff3_level0_col1" class="col_heading level0 col1" >Origin_Total Counts</th>
#       <th id="T_96ff3_level0_col2" class="col_heading level0 col2" >Rate</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Airport_Size</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96ff3_level0_row0" class="row_heading level0 row0" >Medium</th>
#       <td id="T_96ff3_row0_col0" class="data row0 col0" >1354572</td>
#       <td id="T_96ff3_row0_col1" class="data row0 col1" >3719842</td>
#       <td id="T_96ff3_row0_col2" class="data row0 col2" >36.414772</td>
#     </tr>
#     <tr>
#       <th id="T_96ff3_level0_row1" class="row_heading level0 row1" >Large</th>
#       <td id="T_96ff3_row1_col0" class="data row1 col0" >331191</td>
#       <td id="T_96ff3_row1_col1" class="data row1 col1" >934772</td>
#       <td id="T_96ff3_row1_col2" class="data row1 col2" >35.430137</td>
#     </tr>
#     <tr>
#       <th id="T_96ff3_level0_row2" class="row_heading level0 row2" >Small</th>
#       <td id="T_96ff3_row2_col0" class="data row2 col0" >257783</td>
#       <td id="T_96ff3_row2_col1" class="data row2 col1" >924004</td>
#       <td id="T_96ff3_row2_col2" class="data row2 col2" >27.898472</td>
#     </tr>
#   </tbody>
# </table>

# %%
col_order = ["Early Depart_On Time", "DepDelay < 15 min", "DepDelay 16-30 min", "DepDelay 31-60 min","DepDelay > 61", "Cancelled"]
airport_status = flight[['Airport_Size','Flight_Status']]
airport_status = (airport_status.groupby(["Airport_Size"])["Flight_Status"].value_counts(normalize=True).unstack()[col_order])
airport_status.sort_values("Early Depart_On Time").plot(
    kind="barh", stacked=True, width=0.8, edgecolor="black", figsize = (15,2.5))
plt.title("Flight Status by Airport_Size") 
plt.xlabel("Percentage of Flight Status")
plt.ylabel("Airport_Size")

plt.show()
